# %% [markdown]
# # Train and evaluate a 3D Convolutional Neural Network (3dCNN) to classify motor tasks

# %% [markdown]
# <p style='text-align: justify;'>In this notebook we create and train a 3D-Convolutional Neural Network which learns to classify different patterns of whole-brain fMRI statistical parameters (t-scores). In this first approach our goal is to train a classifier that can reliably distinguish between such whole-brain patterns for five limb movements (i.e., left/right hand, left/right foot, and tongue).
#
# </p>

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import os, wandb, torch, time
import pandas as pd
import numpy as np
from glob import glob
from torch.utils.data import DataLoader
from torchinfo import summary
import seaborn as sns
import matplotlib.pyplot as plt

from delphi import mni_template
from delphi.networks.ConvNets import BrainStateClassifier3d
from delphi.utils.datasets import NiftiDataset
from delphi.utils.tools import ToTensor, compute_accuracy, convert_wandb_config, read_config, z_transform_volume
from delphi.utils.plots import confusion_matrix

# you can find all these files in ../utils
from utils.tools import attribute_with_method 
from utils.random import set_random_seed

from tqdm.notebook import tqdm

DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %% [markdown]
# <p style='text-align: justify;'>To make sure that we obtain (almost) the same results for each execution we set the random seed of multiple different librabries (i.e., torch, random, numpy)</p>

# %%
g = set_random_seed(2020) # the project started in the year 2020, hence the seed

# %% [markdown]
# ## Initializations

# %% [markdown]
# In this section, we define and initialize our required variables. We first need to define which classes we want to predict, i.e., the conditions of the motor mapper. We then define a PyTorch dataset; in this case `NiftiDataset` is a custom written Dataset-Class (see https://github.com/PhilippS893/delphi). As is common practice in machine learning projects, we split our data into a training and validation dataset (ratio=80 to 20, respectively).
#
# Note: In case it is necessary to create a null-model, i.e., a neural network that is trained on data where the labels are randomized, one can set the parameter `shuffe_labels=False` to `True`. This is usually done to have a baseline for the null hypothesis that "everything is random".

# %%
class_labels = ["footleft", "footright", "handleft", "handright", "tongue", 
                "loss", "reward", 
                "mental", "random", 
                "body", "face", "place", "tool", 
                "match", "relation", 
                "emotion", "neut", 
                "story", "math"]
data_test = NiftiDataset("../t-maps/test", class_labels, 0, device=DEVICE, transform=ToTensor())

# %%
f1_test.mean()
# Out:
# 0.8763157894736842

# %% [markdown]
# <p style='text-align: justify;'>We now set some parameters required by w&b to properly store information about our trained neural networks.</p>

# %% [markdown]
# # Identify the best fold

# %%
from utils.wandb_funcs import get_wandb_csv

# %%
keys_of_interest = ['group', 'job_type', 'run_name', 'test_accuracy', 'train_acc', 'valid_acc', 
                    'valid_loss', 'best_valid_epoch', 'best_valid_accuracy', 'test_loss', 'train_loss']
wandb_df = get_wandb_csv("philis893", "thesis", "full-hcp", keys_of_interest, job_name="CV-7folds-real", overwrite=True)

real_runs = wandb_df[wandb_df.job_type == "CV-7folds-real"]
# sort according to best_valid_accuracy (desc), test_accuracy (desc), and test_loss (asc). Take the first entry => best fold
real_runs_sorted = real_runs.sort_values(["best_valid_accuracy", "test_accuracy", "test_loss"], ascending=[False, False, True])
real_runs_sorted.head(1)
# Out:
# {'entity': 'philis893', 'project': 'thesis', 'filters': {'group_name': {'$regex': 'full-hcp.*'}, 'jobType': 'CV-7folds-real'}, 'order': '-created_at', '_sweeps': {}, 'client': <wandb.apis.public.RetryingClient object at 0x7f571376ca90>, 'variables': {'project': 'thesis', 'entity': 'philis893', 'order': '-created_at', 'filters': '{"group_name": {"$regex": "full-hcp.*"}, "jobType": "CV-7folds-real"}'}, 'per_page': 50, 'objects': [], 'index': -1, 'last_response': None}
#       group        job_type           run_name  test_accuracy  train_acc  \
# 5  full-hcp  CV-7folds-real  seed-2020_fold-01       0.876316   0.924561
#
#    valid_acc  valid_loss  best_valid_epoch  best_valid_accuracy  test_loss  \
# 5   0.860526    0.334964                50             0.902632   0.354409
#
#    train_loss
# 5    0.181635

# %%
BEST_FOLD = 1;

# %% [markdown]
# # Investigate what information was deemed relevant (XAI)

# %%
from captum.attr import GuidedBackprop
from zennit.rules import Epsilon, Gamma, Pass
from zennit.types import Convolution, Linear, Activation
from zennit.composites import LayerMapComposite
from delphi.utils.tools import save_in_mni
from utils.tools import attribute_with_method

composite_lrp_map = [
    (Activation, Pass()),
    (Convolution, Gamma(gamma=.25)),
    (Linear, Epsilon(epsilon=0)),
]

LRP = LayerMapComposite(
    layer_map=composite_lrp_map,
)
LRP.__name__ = 'LRP'

# %%
label_order = "real"

fold = BEST_FOLD

attributor_method = [LRP, GuidedBackprop]

for i, method in enumerate(attributor_method):

    method_name = str(method.__name__).lower()
    
    for fold in range(7):
        # load the trained network
        model = BrainStateClassifier3d(f"models/CV-7folds-{label_order}/seed-2020_fold-{fold:02d}")
        model.to(torch.device("cpu"));
        model.eval()

        out_dir_name = f"{method_name}/{label_order}/fold-{fold:02d}"
        if not os.path.exists(out_dir_name):
            os.makedirs(out_dir_name)

        for j in range(len(class_labels)):

            print(f"Running {method_name} on {class_labels[j]}")

            out_fname = os.path.join(out_dir_name, '%s.nii.gz' % class_labels[j])
            if os.path.isfile(out_fname):
                print(f"{out_fname} already exists. Skipping")
                continue

            dl = DataLoader(
                NiftiDataset('../t-maps/test', [class_labels[j]], 0, device=torch.device("cpu"), transform=ToTensor()),
                batch_size=20, shuffle=False, num_workers=0
            )

            for i, (volume, target) in enumerate(dl):

                attribution = attribute_with_method(method, model, volume, target)

                subject_attr = np.moveaxis(attribution.squeeze().detach().numpy(), 0, -1)
                subject_attr = z_transform_volume(subject_attr)
                avg_attr = subject_attr.mean(axis=-1)

            save_in_mni(subject_attr, out_fname)

            avg_out_name = os.path.join(out_dir_name, "avg")
            if not os.path.exists(avg_out_name):
                os.makedirs(avg_out_name)
            save_in_mni(avg_attr, os.path.join(avg_out_name, '%s.nii.gz' % class_labels[j]))
# Out:
# Loading from config file models/CV-7folds-real/seed-2020_fold-00/config.yaml
# Running lrp on footleft
# Saving lrp/real/fold-00/footleft.nii.gz
# Saving lrp/real/fold-00/avg/footleft.nii.gz
# Running lrp on footright
# Saving lrp/real/fold-00/footright.nii.gz
# Saving lrp/real/fold-00/avg/footright.nii.gz
# Running lrp on handleft
# Saving lrp/real/fold-00/handleft.nii.gz
# Saving lrp/real/fold-00/avg/handleft.nii.gz
# Running lrp on handright
# Saving lrp/real/fold-00/handright.nii.gz
# Saving lrp/real/fold-00/avg/handright.nii.gz
# Running lrp on tongue
# Saving lrp/real/fold-00/tongue.nii.gz
# Saving lrp/real/fold-00/avg/tongue.nii.gz
# Running lrp on loss
# Saving lrp/real/fold-00/loss.nii.gz
# Saving lrp/real/fold-00/avg/loss.nii.gz
# Running lrp on reward
# Saving lrp/real/fold-00/reward.nii.gz
# Saving lrp/real/fold-00/avg/reward.nii.gz
# Running lrp on mental
# Saving lrp/real/fold-00/mental.nii.gz
# Saving lrp/real/fold-00/avg/mental.nii.gz
# Running lrp on random
# Saving lrp/real/fold-00/random.nii.gz
# Saving lrp/real/fold-00/avg/random.nii.gz
# Running lrp on body
# Saving lrp/real/fold-00/body.nii.gz
# Saving lrp/real/fold-00/avg/body.nii.gz
# Running lrp on face
# Saving lrp/real/fold-00/face.nii.gz
# Saving lrp/real/fold-00/avg/face.nii.gz
# Running lrp on place
# Saving lrp/real/fold-00/place.nii.gz
# Saving lrp/real/fold-00/avg/place.nii.gz
# Running lrp on tool
# Saving lrp/real/fold-00/tool.nii.gz
# Saving lrp/real/fold-00/avg/tool.nii.gz
# Running lrp on match
# Saving lrp/real/fold-00/match.nii.gz
# Saving lrp/real/fold-00/avg/match.nii.gz
# Running lrp on relation
# Saving lrp/real/fold-00/relation.nii.gz
# Saving lrp/real/fold-00/avg/relation.nii.gz
# Running lrp on emotion
# Saving lrp/real/fold-00/emotion.nii.gz
# Saving lrp/real/fold-00/avg/emotion.nii.gz
# Running lrp on neut
# Saving lrp/real/fold-00/neut.nii.gz
# Saving lrp/real/fold-00/avg/neut.nii.gz
# Running lrp on story
# Saving lrp/real/fold-00/story.nii.gz
# Saving lrp/real/fold-00/avg/story.nii.gz
# Running lrp on math
# Saving lrp/real/fold-00/math.nii.gz
# Saving lrp/real/fold-00/avg/math.nii.gz
# Loading from config file models/CV-7folds-real/seed-2020_fold-01/config.yaml
# Running lrp on footleft
# lrp/real/fold-01/footleft.nii.gz already exists. Skipping
# Running lrp on footright
# lrp/real/fold-01/footright.nii.gz already exists. Skipping
# Running lrp on handleft
# lrp/real/fold-01/handleft.nii.gz already exists. Skipping
# Running lrp on handright
# lrp/real/fold-01/handright.nii.gz already exists. Skipping
# Running lrp on tongue
# lrp/real/fold-01/tongue.nii.gz already exists. Skipping
# Running lrp on loss
# lrp/real/fold-01/loss.nii.gz already exists. Skipping
# Running lrp on reward
# lrp/real/fold-01/reward.nii.gz already exists. Skipping
# Running lrp on mental
# lrp/real/fold-01/mental.nii.gz already exists. Skipping
# Running lrp on random
# lrp/real/fold-01/random.nii.gz already exists. Skipping
# Running lrp on body
# lrp/real/fold-01/body.nii.gz already exists. Skipping
# Running lrp on face
# lrp/real/fold-01/face.nii.gz already exists. Skipping
# Running lrp on place
# lrp/real/fold-01/place.nii.gz already exists. Skipping
# Running lrp on tool
# lrp/real/fold-01/tool.nii.gz already exists. Skipping
# Running lrp on match
# lrp/real/fold-01/match.nii.gz already exists. Skipping
# Running lrp on relation
# lrp/real/fold-01/relation.nii.gz already exists. Skipping
# Running lrp on emotion
# lrp/real/fold-01/emotion.nii.gz already exists. Skipping
# Running lrp on neut
# lrp/real/fold-01/neut.nii.gz already exists. Skipping
# Running lrp on story
# lrp/real/fold-01/story.nii.gz already exists. Skipping
# Running lrp on math
# lrp/real/fold-01/math.nii.gz already exists. Skipping
# Loading from config file models/CV-7folds-real/seed-2020_fold-02/config.yaml
# Running lrp on footleft
# Saving lrp/real/fold-02/footleft.nii.gz
# Saving lrp/real/fold-02/avg/footleft.nii.gz
# Running lrp on footright
# Saving lrp/real/fold-02/footright.nii.gz
# Saving lrp/real/fold-02/avg/footright.nii.gz
# Running lrp on handleft
# Saving lrp/real/fold-02/handleft.nii.gz
# Saving lrp/real/fold-02/avg/handleft.nii.gz
# Running lrp on handright
# Saving lrp/real/fold-02/handright.nii.gz
# Saving lrp/real/fold-02/avg/handright.nii.gz
# Running lrp on tongue
# Saving lrp/real/fold-02/tongue.nii.gz
# Saving lrp/real/fold-02/avg/tongue.nii.gz
# Running lrp on loss
# Saving lrp/real/fold-02/loss.nii.gz
# Saving lrp/real/fold-02/avg/loss.nii.gz
# Running lrp on reward
# Saving lrp/real/fold-02/reward.nii.gz
# Saving lrp/real/fold-02/avg/reward.nii.gz
# Running lrp on mental
# Saving lrp/real/fold-02/mental.nii.gz
# Saving lrp/real/fold-02/avg/mental.nii.gz
# Running lrp on random
# Saving lrp/real/fold-02/random.nii.gz
# Saving lrp/real/fold-02/avg/random.nii.gz
# Running lrp on body
# Saving lrp/real/fold-02/body.nii.gz
# Saving lrp/real/fold-02/avg/body.nii.gz
# Running lrp on face
# Saving lrp/real/fold-02/face.nii.gz
# Saving lrp/real/fold-02/avg/face.nii.gz
# Running lrp on place
# Saving lrp/real/fold-02/place.nii.gz
# Saving lrp/real/fold-02/avg/place.nii.gz
# Running lrp on tool
# Saving lrp/real/fold-02/tool.nii.gz
# Saving lrp/real/fold-02/avg/tool.nii.gz
# Running lrp on match
# Saving lrp/real/fold-02/match.nii.gz
# Saving lrp/real/fold-02/avg/match.nii.gz
# Running lrp on relation
# Saving lrp/real/fold-02/relation.nii.gz
# Saving lrp/real/fold-02/avg/relation.nii.gz
# Running lrp on emotion
# Saving lrp/real/fold-02/emotion.nii.gz
# Saving lrp/real/fold-02/avg/emotion.nii.gz
# Running lrp on neut
# Saving lrp/real/fold-02/neut.nii.gz
# Saving lrp/real/fold-02/avg/neut.nii.gz
# Running lrp on story
# Saving lrp/real/fold-02/story.nii.gz
# Saving lrp/real/fold-02/avg/story.nii.gz
# Running lrp on math
# Saving lrp/real/fold-02/math.nii.gz
# Saving lrp/real/fold-02/avg/math.nii.gz
# Loading from config file models/CV-7folds-real/seed-2020_fold-03/config.yaml
# Running lrp on footleft
# Saving lrp/real/fold-03/footleft.nii.gz
# Saving lrp/real/fold-03/avg/footleft.nii.gz
# Running lrp on footright
# Saving lrp/real/fold-03/footright.nii.gz
# Saving lrp/real/fold-03/avg/footright.nii.gz
# Running lrp on handleft
# Saving lrp/real/fold-03/handleft.nii.gz
# Saving lrp/real/fold-03/avg/handleft.nii.gz
# Running lrp on handright
# Saving lrp/real/fold-03/handright.nii.gz
# Saving lrp/real/fold-03/avg/handright.nii.gz
# Running lrp on tongue
# Saving lrp/real/fold-03/tongue.nii.gz
# Saving lrp/real/fold-03/avg/tongue.nii.gz
# Running lrp on loss
# Saving lrp/real/fold-03/loss.nii.gz
# Saving lrp/real/fold-03/avg/loss.nii.gz
# Running lrp on reward
# Saving lrp/real/fold-03/reward.nii.gz
# Saving lrp/real/fold-03/avg/reward.nii.gz
# Running lrp on mental
# Saving lrp/real/fold-03/mental.nii.gz
# Saving lrp/real/fold-03/avg/mental.nii.gz
# Running lrp on random
# Saving lrp/real/fold-03/random.nii.gz
# Saving lrp/real/fold-03/avg/random.nii.gz
# Running lrp on body
# Saving lrp/real/fold-03/body.nii.gz
# Saving lrp/real/fold-03/avg/body.nii.gz
# Running lrp on face
# Saving lrp/real/fold-03/face.nii.gz
# Saving lrp/real/fold-03/avg/face.nii.gz
# Running lrp on place
# Saving lrp/real/fold-03/place.nii.gz
# Saving lrp/real/fold-03/avg/place.nii.gz
# Running lrp on tool
# Saving lrp/real/fold-03/tool.nii.gz
# Saving lrp/real/fold-03/avg/tool.nii.gz
# Running lrp on match
# Saving lrp/real/fold-03/match.nii.gz
# Saving lrp/real/fold-03/avg/match.nii.gz
# Running lrp on relation
# Saving lrp/real/fold-03/relation.nii.gz
# Saving lrp/real/fold-03/avg/relation.nii.gz
# Running lrp on emotion
# Saving lrp/real/fold-03/emotion.nii.gz
# Saving lrp/real/fold-03/avg/emotion.nii.gz
# Running lrp on neut
# Saving lrp/real/fold-03/neut.nii.gz
# Saving lrp/real/fold-03/avg/neut.nii.gz
# Running lrp on story
# Saving lrp/real/fold-03/story.nii.gz
# Saving lrp/real/fold-03/avg/story.nii.gz
# Running lrp on math
# Saving lrp/real/fold-03/math.nii.gz
# Saving lrp/real/fold-03/avg/math.nii.gz
# Loading from config file models/CV-7folds-real/seed-2020_fold-04/config.yaml
# Running lrp on footleft
# Saving lrp/real/fold-04/footleft.nii.gz
# Saving lrp/real/fold-04/avg/footleft.nii.gz
# Running lrp on footright
# Saving lrp/real/fold-04/footright.nii.gz
# Saving lrp/real/fold-04/avg/footright.nii.gz
# Running lrp on handleft
# Saving lrp/real/fold-04/handleft.nii.gz
# Saving lrp/real/fold-04/avg/handleft.nii.gz
# Running lrp on handright
# Saving lrp/real/fold-04/handright.nii.gz
# Saving lrp/real/fold-04/avg/handright.nii.gz
# Running lrp on tongue
# Saving lrp/real/fold-04/tongue.nii.gz
# Saving lrp/real/fold-04/avg/tongue.nii.gz
# Running lrp on loss
# Saving lrp/real/fold-04/loss.nii.gz
# Saving lrp/real/fold-04/avg/loss.nii.gz
# Running lrp on reward
# Saving lrp/real/fold-04/reward.nii.gz
# Saving lrp/real/fold-04/avg/reward.nii.gz
# Running lrp on mental
# Saving lrp/real/fold-04/mental.nii.gz
# Saving lrp/real/fold-04/avg/mental.nii.gz
# Running lrp on random
# Saving lrp/real/fold-04/random.nii.gz
# Saving lrp/real/fold-04/avg/random.nii.gz
# Running lrp on body
# Saving lrp/real/fold-04/body.nii.gz
# Saving lrp/real/fold-04/avg/body.nii.gz
# Running lrp on face
# Saving lrp/real/fold-04/face.nii.gz
# Saving lrp/real/fold-04/avg/face.nii.gz
# Running lrp on place
# Saving lrp/real/fold-04/place.nii.gz
# Saving lrp/real/fold-04/avg/place.nii.gz
# Running lrp on tool
# Saving lrp/real/fold-04/tool.nii.gz
# Saving lrp/real/fold-04/avg/tool.nii.gz
# Running lrp on match
# Saving lrp/real/fold-04/match.nii.gz
# Saving lrp/real/fold-04/avg/match.nii.gz
# Running lrp on relation
# Saving lrp/real/fold-04/relation.nii.gz
# Saving lrp/real/fold-04/avg/relation.nii.gz
# Running lrp on emotion
# Saving lrp/real/fold-04/emotion.nii.gz
# Saving lrp/real/fold-04/avg/emotion.nii.gz
# Running lrp on neut
# Saving lrp/real/fold-04/neut.nii.gz
# Saving lrp/real/fold-04/avg/neut.nii.gz
# Running lrp on story
# Saving lrp/real/fold-04/story.nii.gz
# Saving lrp/real/fold-04/avg/story.nii.gz
# Running lrp on math
# Saving lrp/real/fold-04/math.nii.gz
# Saving lrp/real/fold-04/avg/math.nii.gz
# Loading from config file models/CV-7folds-real/seed-2020_fold-05/config.yaml
# Running lrp on footleft
# Saving lrp/real/fold-05/footleft.nii.gz
# Saving lrp/real/fold-05/avg/footleft.nii.gz
# Running lrp on footright
# Saving lrp/real/fold-05/footright.nii.gz
# Saving lrp/real/fold-05/avg/footright.nii.gz
# Running lrp on handleft
# Saving lrp/real/fold-05/handleft.nii.gz
# Saving lrp/real/fold-05/avg/handleft.nii.gz
# Running lrp on handright
# Saving lrp/real/fold-05/handright.nii.gz
# Saving lrp/real/fold-05/avg/handright.nii.gz
# Running lrp on tongue
# Saving lrp/real/fold-05/tongue.nii.gz
# Saving lrp/real/fold-05/avg/tongue.nii.gz
# Running lrp on loss
# Saving lrp/real/fold-05/loss.nii.gz
# Saving lrp/real/fold-05/avg/loss.nii.gz
# Running lrp on reward
# Saving lrp/real/fold-05/reward.nii.gz
# Saving lrp/real/fold-05/avg/reward.nii.gz
# Running lrp on mental
# Saving lrp/real/fold-05/mental.nii.gz
# Saving lrp/real/fold-05/avg/mental.nii.gz
# Running lrp on random
# Saving lrp/real/fold-05/random.nii.gz
# Saving lrp/real/fold-05/avg/random.nii.gz
# Running lrp on body
# Saving lrp/real/fold-05/body.nii.gz
# Saving lrp/real/fold-05/avg/body.nii.gz
# Running lrp on face
# Saving lrp/real/fold-05/face.nii.gz
# Saving lrp/real/fold-05/avg/face.nii.gz
# Running lrp on place
# Saving lrp/real/fold-05/place.nii.gz
# Saving lrp/real/fold-05/avg/place.nii.gz
# Running lrp on tool
# Saving lrp/real/fold-05/tool.nii.gz
# Saving lrp/real/fold-05/avg/tool.nii.gz
# Running lrp on match
# Saving lrp/real/fold-05/match.nii.gz
# Saving lrp/real/fold-05/avg/match.nii.gz
# Running lrp on relation
# Saving lrp/real/fold-05/relation.nii.gz
# Saving lrp/real/fold-05/avg/relation.nii.gz
# Running lrp on emotion
# Saving lrp/real/fold-05/emotion.nii.gz
# Saving lrp/real/fold-05/avg/emotion.nii.gz
# Running lrp on neut
# Saving lrp/real/fold-05/neut.nii.gz
# Saving lrp/real/fold-05/avg/neut.nii.gz
# Running lrp on story
# Saving lrp/real/fold-05/story.nii.gz
# Saving lrp/real/fold-05/avg/story.nii.gz
# Running lrp on math
# Saving lrp/real/fold-05/math.nii.gz
# Saving lrp/real/fold-05/avg/math.nii.gz
# Loading from config file models/CV-7folds-real/seed-2020_fold-06/config.yaml
# Running lrp on footleft
# Saving lrp/real/fold-06/footleft.nii.gz
# Saving lrp/real/fold-06/avg/footleft.nii.gz
# Running lrp on footright
# Saving lrp/real/fold-06/footright.nii.gz
# Saving lrp/real/fold-06/avg/footright.nii.gz
# Running lrp on handleft
# Saving lrp/real/fold-06/handleft.nii.gz
# Saving lrp/real/fold-06/avg/handleft.nii.gz
# Running lrp on handright
# Saving lrp/real/fold-06/handright.nii.gz
# Saving lrp/real/fold-06/avg/handright.nii.gz
# Running lrp on tongue
# Saving lrp/real/fold-06/tongue.nii.gz
# Saving lrp/real/fold-06/avg/tongue.nii.gz
# Running lrp on loss
# Saving lrp/real/fold-06/loss.nii.gz
# Saving lrp/real/fold-06/avg/loss.nii.gz
# Running lrp on reward
# Saving lrp/real/fold-06/reward.nii.gz
# Saving lrp/real/fold-06/avg/reward.nii.gz
# Running lrp on mental
# Saving lrp/real/fold-06/mental.nii.gz
# Saving lrp/real/fold-06/avg/mental.nii.gz
# Running lrp on random
# Saving lrp/real/fold-06/random.nii.gz
# Saving lrp/real/fold-06/avg/random.nii.gz
# Running lrp on body
# Saving lrp/real/fold-06/body.nii.gz
# Saving lrp/real/fold-06/avg/body.nii.gz
# Running lrp on face
# Saving lrp/real/fold-06/face.nii.gz
# Saving lrp/real/fold-06/avg/face.nii.gz
# Running lrp on place
# Saving lrp/real/fold-06/place.nii.gz
# Saving lrp/real/fold-06/avg/place.nii.gz
# Running lrp on tool
# Saving lrp/real/fold-06/tool.nii.gz
# Saving lrp/real/fold-06/avg/tool.nii.gz
# Running lrp on match
# Saving lrp/real/fold-06/match.nii.gz
# Saving lrp/real/fold-06/avg/match.nii.gz
# Running lrp on relation
# Saving lrp/real/fold-06/relation.nii.gz
# Saving lrp/real/fold-06/avg/relation.nii.gz
# Running lrp on emotion
# Saving lrp/real/fold-06/emotion.nii.gz
# Saving lrp/real/fold-06/avg/emotion.nii.gz
# Running lrp on neut
# Saving lrp/real/fold-06/neut.nii.gz
# Saving lrp/real/fold-06/avg/neut.nii.gz
# Running lrp on story
# Saving lrp/real/fold-06/story.nii.gz
# Saving lrp/real/fold-06/avg/story.nii.gz
# Running lrp on math
# Saving lrp/real/fold-06/math.nii.gz
# Saving lrp/real/fold-06/avg/math.nii.gz
# Loading from config file models/CV-7folds-real/seed-2020_fold-00/config.yaml
# Running guidedbackprop on footleft
# guidedbackprop/real/fold-00/footleft.nii.gz already exists. Skipping
# Running guidedbackprop on footright
# guidedbackprop/real/fold-00/footright.nii.gz already exists. Skipping
# Running guidedbackprop on handleft
# guidedbackprop/real/fold-00/handleft.nii.gz already exists. Skipping
# Running guidedbackprop on handright
# guidedbackprop/real/fold-00/handright.nii.gz already exists. Skipping
# Running guidedbackprop on tongue
# guidedbackprop/real/fold-00/tongue.nii.gz already exists. Skipping
# Running guidedbackprop on loss
# guidedbackprop/real/fold-00/loss.nii.gz already exists. Skipping
# Running guidedbackprop on reward
# guidedbackprop/real/fold-00/reward.nii.gz already exists. Skipping
# Running guidedbackprop on mental
# guidedbackprop/real/fold-00/mental.nii.gz already exists. Skipping
# Running guidedbackprop on random
# guidedbackprop/real/fold-00/random.nii.gz already exists. Skipping
# Running guidedbackprop on body
# guidedbackprop/real/fold-00/body.nii.gz already exists. Skipping
# Running guidedbackprop on face
# guidedbackprop/real/fold-00/face.nii.gz already exists. Skipping
# Running guidedbackprop on place
# Saving guidedbackprop/real/fold-00/place.nii.gz
# Saving guidedbackprop/real/fold-00/avg/place.nii.gz
# Running guidedbackprop on tool
# Saving guidedbackprop/real/fold-00/tool.nii.gz
# Saving guidedbackprop/real/fold-00/avg/tool.nii.gz
# Running guidedbackprop on match
# Saving guidedbackprop/real/fold-00/match.nii.gz
# Saving guidedbackprop/real/fold-00/avg/match.nii.gz
# Running guidedbackprop on relation
# Saving guidedbackprop/real/fold-00/relation.nii.gz
# Saving guidedbackprop/real/fold-00/avg/relation.nii.gz
# Running guidedbackprop on emotion
# Saving guidedbackprop/real/fold-00/emotion.nii.gz
# Saving guidedbackprop/real/fold-00/avg/emotion.nii.gz
# Running guidedbackprop on neut
# Saving guidedbackprop/real/fold-00/neut.nii.gz
# Saving guidedbackprop/real/fold-00/avg/neut.nii.gz
# Running guidedbackprop on story
# Saving guidedbackprop/real/fold-00/story.nii.gz
# Saving guidedbackprop/real/fold-00/avg/story.nii.gz
# Running guidedbackprop on math
# Saving guidedbackprop/real/fold-00/math.nii.gz
# Saving guidedbackprop/real/fold-00/avg/math.nii.gz
# Loading from config file models/CV-7folds-real/seed-2020_fold-01/config.yaml
# Running guidedbackprop on footleft
# guidedbackprop/real/fold-01/footleft.nii.gz already exists. Skipping
# Running guidedbackprop on footright
# guidedbackprop/real/fold-01/footright.nii.gz already exists. Skipping
# Running guidedbackprop on handleft
# guidedbackprop/real/fold-01/handleft.nii.gz already exists. Skipping
# Running guidedbackprop on handright
# guidedbackprop/real/fold-01/handright.nii.gz already exists. Skipping
# Running guidedbackprop on tongue
# guidedbackprop/real/fold-01/tongue.nii.gz already exists. Skipping
# Running guidedbackprop on loss
# guidedbackprop/real/fold-01/loss.nii.gz already exists. Skipping
# Running guidedbackprop on reward
# guidedbackprop/real/fold-01/reward.nii.gz already exists. Skipping
# Running guidedbackprop on mental
# guidedbackprop/real/fold-01/mental.nii.gz already exists. Skipping
# Running guidedbackprop on random
# guidedbackprop/real/fold-01/random.nii.gz already exists. Skipping
# Running guidedbackprop on body
# guidedbackprop/real/fold-01/body.nii.gz already exists. Skipping
# Running guidedbackprop on face
# guidedbackprop/real/fold-01/face.nii.gz already exists. Skipping
# Running guidedbackprop on place
# guidedbackprop/real/fold-01/place.nii.gz already exists. Skipping
# Running guidedbackprop on tool
# guidedbackprop/real/fold-01/tool.nii.gz already exists. Skipping
# Running guidedbackprop on match
# guidedbackprop/real/fold-01/match.nii.gz already exists. Skipping
# Running guidedbackprop on relation
# guidedbackprop/real/fold-01/relation.nii.gz already exists. Skipping
# Running guidedbackprop on emotion
# guidedbackprop/real/fold-01/emotion.nii.gz already exists. Skipping
# Running guidedbackprop on neut
# guidedbackprop/real/fold-01/neut.nii.gz already exists. Skipping
# Running guidedbackprop on story
# guidedbackprop/real/fold-01/story.nii.gz already exists. Skipping
# Running guidedbackprop on math
# guidedbackprop/real/fold-01/math.nii.gz already exists. Skipping
# Loading from config file models/CV-7folds-real/seed-2020_fold-02/config.yaml
# Running guidedbackprop on footleft
# Saving guidedbackprop/real/fold-02/footleft.nii.gz
# Saving guidedbackprop/real/fold-02/avg/footleft.nii.gz
# Running guidedbackprop on footright
# Saving guidedbackprop/real/fold-02/footright.nii.gz
# Saving guidedbackprop/real/fold-02/avg/footright.nii.gz
# Running guidedbackprop on handleft
# Saving guidedbackprop/real/fold-02/handleft.nii.gz
# Saving guidedbackprop/real/fold-02/avg/handleft.nii.gz
# Running guidedbackprop on handright
# Saving guidedbackprop/real/fold-02/handright.nii.gz
# Saving guidedbackprop/real/fold-02/avg/handright.nii.gz
# Running guidedbackprop on tongue
# Saving guidedbackprop/real/fold-02/tongue.nii.gz
# Saving guidedbackprop/real/fold-02/avg/tongue.nii.gz
# Running guidedbackprop on loss
# Saving guidedbackprop/real/fold-02/loss.nii.gz
# Saving guidedbackprop/real/fold-02/avg/loss.nii.gz
# Running guidedbackprop on reward
# Saving guidedbackprop/real/fold-02/reward.nii.gz
# Saving guidedbackprop/real/fold-02/avg/reward.nii.gz
# Running guidedbackprop on mental
# Saving guidedbackprop/real/fold-02/mental.nii.gz
# Saving guidedbackprop/real/fold-02/avg/mental.nii.gz
# Running guidedbackprop on random
# Saving guidedbackprop/real/fold-02/random.nii.gz
# Saving guidedbackprop/real/fold-02/avg/random.nii.gz
# Running guidedbackprop on body
# Saving guidedbackprop/real/fold-02/body.nii.gz
# Saving guidedbackprop/real/fold-02/avg/body.nii.gz
# Running guidedbackprop on face
# Saving guidedbackprop/real/fold-02/face.nii.gz
# Saving guidedbackprop/real/fold-02/avg/face.nii.gz
# Running guidedbackprop on place
# Saving guidedbackprop/real/fold-02/place.nii.gz
# Saving guidedbackprop/real/fold-02/avg/place.nii.gz
# Running guidedbackprop on tool
# Saving guidedbackprop/real/fold-02/tool.nii.gz
# Saving guidedbackprop/real/fold-02/avg/tool.nii.gz
# Running guidedbackprop on match
# Saving guidedbackprop/real/fold-02/match.nii.gz
# Saving guidedbackprop/real/fold-02/avg/match.nii.gz
# Running guidedbackprop on relation
# Saving guidedbackprop/real/fold-02/relation.nii.gz
# Saving guidedbackprop/real/fold-02/avg/relation.nii.gz
# Running guidedbackprop on emotion
# Saving guidedbackprop/real/fold-02/emotion.nii.gz
# Saving guidedbackprop/real/fold-02/avg/emotion.nii.gz
# Running guidedbackprop on neut
# Saving guidedbackprop/real/fold-02/neut.nii.gz
# Saving guidedbackprop/real/fold-02/avg/neut.nii.gz
# Running guidedbackprop on story
# Saving guidedbackprop/real/fold-02/story.nii.gz
# Saving guidedbackprop/real/fold-02/avg/story.nii.gz
# Running guidedbackprop on math
# Saving guidedbackprop/real/fold-02/math.nii.gz
# Saving guidedbackprop/real/fold-02/avg/math.nii.gz
# Loading from config file models/CV-7folds-real/seed-2020_fold-03/config.yaml
# Running guidedbackprop on footleft
# Saving guidedbackprop/real/fold-03/footleft.nii.gz
# Saving guidedbackprop/real/fold-03/avg/footleft.nii.gz
# Running guidedbackprop on footright
# Saving guidedbackprop/real/fold-03/footright.nii.gz
# Saving guidedbackprop/real/fold-03/avg/footright.nii.gz
# Running guidedbackprop on handleft
# Saving guidedbackprop/real/fold-03/handleft.nii.gz
# Saving guidedbackprop/real/fold-03/avg/handleft.nii.gz
# Running guidedbackprop on handright
# Saving guidedbackprop/real/fold-03/handright.nii.gz
# Saving guidedbackprop/real/fold-03/avg/handright.nii.gz
# Running guidedbackprop on tongue
# Saving guidedbackprop/real/fold-03/tongue.nii.gz
# Saving guidedbackprop/real/fold-03/avg/tongue.nii.gz
# Running guidedbackprop on loss
# Saving guidedbackprop/real/fold-03/loss.nii.gz
# Saving guidedbackprop/real/fold-03/avg/loss.nii.gz
# Running guidedbackprop on reward
# Saving guidedbackprop/real/fold-03/reward.nii.gz
# Saving guidedbackprop/real/fold-03/avg/reward.nii.gz
# Running guidedbackprop on mental
# Saving guidedbackprop/real/fold-03/mental.nii.gz
# Saving guidedbackprop/real/fold-03/avg/mental.nii.gz
# Running guidedbackprop on random
# Saving guidedbackprop/real/fold-03/random.nii.gz
# Saving guidedbackprop/real/fold-03/avg/random.nii.gz
# Running guidedbackprop on body
# Saving guidedbackprop/real/fold-03/body.nii.gz
# Saving guidedbackprop/real/fold-03/avg/body.nii.gz
# Running guidedbackprop on face
# Saving guidedbackprop/real/fold-03/face.nii.gz
# Saving guidedbackprop/real/fold-03/avg/face.nii.gz
# Running guidedbackprop on place
# Saving guidedbackprop/real/fold-03/place.nii.gz
# Saving guidedbackprop/real/fold-03/avg/place.nii.gz
# Running guidedbackprop on tool
# Saving guidedbackprop/real/fold-03/tool.nii.gz
# Saving guidedbackprop/real/fold-03/avg/tool.nii.gz
# Running guidedbackprop on match
# Saving guidedbackprop/real/fold-03/match.nii.gz
# Saving guidedbackprop/real/fold-03/avg/match.nii.gz
# Running guidedbackprop on relation
# Saving guidedbackprop/real/fold-03/relation.nii.gz
# Saving guidedbackprop/real/fold-03/avg/relation.nii.gz
# Running guidedbackprop on emotion
# Saving guidedbackprop/real/fold-03/emotion.nii.gz
# Saving guidedbackprop/real/fold-03/avg/emotion.nii.gz
# Running guidedbackprop on neut
# Saving guidedbackprop/real/fold-03/neut.nii.gz
# Saving guidedbackprop/real/fold-03/avg/neut.nii.gz
# Running guidedbackprop on story
# Saving guidedbackprop/real/fold-03/story.nii.gz
# Saving guidedbackprop/real/fold-03/avg/story.nii.gz
# Running guidedbackprop on math
# Saving guidedbackprop/real/fold-03/math.nii.gz
# Saving guidedbackprop/real/fold-03/avg/math.nii.gz
# Loading from config file models/CV-7folds-real/seed-2020_fold-04/config.yaml
# Running guidedbackprop on footleft
# Saving guidedbackprop/real/fold-04/footleft.nii.gz
# Saving guidedbackprop/real/fold-04/avg/footleft.nii.gz
# Running guidedbackprop on footright
# Saving guidedbackprop/real/fold-04/footright.nii.gz
# Saving guidedbackprop/real/fold-04/avg/footright.nii.gz
# Running guidedbackprop on handleft
# Saving guidedbackprop/real/fold-04/handleft.nii.gz
# Saving guidedbackprop/real/fold-04/avg/handleft.nii.gz
# Running guidedbackprop on handright
# Saving guidedbackprop/real/fold-04/handright.nii.gz
# Saving guidedbackprop/real/fold-04/avg/handright.nii.gz
# Running guidedbackprop on tongue
# Saving guidedbackprop/real/fold-04/tongue.nii.gz
# Saving guidedbackprop/real/fold-04/avg/tongue.nii.gz
# Running guidedbackprop on loss
# Saving guidedbackprop/real/fold-04/loss.nii.gz
# Saving guidedbackprop/real/fold-04/avg/loss.nii.gz
# Running guidedbackprop on reward
# Saving guidedbackprop/real/fold-04/reward.nii.gz
# Saving guidedbackprop/real/fold-04/avg/reward.nii.gz
# Running guidedbackprop on mental
# Saving guidedbackprop/real/fold-04/mental.nii.gz
# Saving guidedbackprop/real/fold-04/avg/mental.nii.gz
# Running guidedbackprop on random
# Saving guidedbackprop/real/fold-04/random.nii.gz
# Saving guidedbackprop/real/fold-04/avg/random.nii.gz
# Running guidedbackprop on body
# Saving guidedbackprop/real/fold-04/body.nii.gz
# Saving guidedbackprop/real/fold-04/avg/body.nii.gz
# Running guidedbackprop on face
# Saving guidedbackprop/real/fold-04/face.nii.gz
# Saving guidedbackprop/real/fold-04/avg/face.nii.gz
# Running guidedbackprop on place
# Saving guidedbackprop/real/fold-04/place.nii.gz
# Saving guidedbackprop/real/fold-04/avg/place.nii.gz
# Running guidedbackprop on tool
# Saving guidedbackprop/real/fold-04/tool.nii.gz
# Saving guidedbackprop/real/fold-04/avg/tool.nii.gz
# Running guidedbackprop on match
# Saving guidedbackprop/real/fold-04/match.nii.gz
# Saving guidedbackprop/real/fold-04/avg/match.nii.gz
# Running guidedbackprop on relation
# Saving guidedbackprop/real/fold-04/relation.nii.gz
# Saving guidedbackprop/real/fold-04/avg/relation.nii.gz
# Running guidedbackprop on emotion
# Saving guidedbackprop/real/fold-04/emotion.nii.gz
# Saving guidedbackprop/real/fold-04/avg/emotion.nii.gz
# Running guidedbackprop on neut
# Saving guidedbackprop/real/fold-04/neut.nii.gz
# Saving guidedbackprop/real/fold-04/avg/neut.nii.gz
# Running guidedbackprop on story
# Saving guidedbackprop/real/fold-04/story.nii.gz
# Saving guidedbackprop/real/fold-04/avg/story.nii.gz
# Running guidedbackprop on math
# Saving guidedbackprop/real/fold-04/math.nii.gz
# Saving guidedbackprop/real/fold-04/avg/math.nii.gz
# Loading from config file models/CV-7folds-real/seed-2020_fold-05/config.yaml
# Running guidedbackprop on footleft
# Saving guidedbackprop/real/fold-05/footleft.nii.gz
# Saving guidedbackprop/real/fold-05/avg/footleft.nii.gz
# Running guidedbackprop on footright
# Saving guidedbackprop/real/fold-05/footright.nii.gz
# Saving guidedbackprop/real/fold-05/avg/footright.nii.gz
# Running guidedbackprop on handleft
# Saving guidedbackprop/real/fold-05/handleft.nii.gz
# Saving guidedbackprop/real/fold-05/avg/handleft.nii.gz
# Running guidedbackprop on handright
# Saving guidedbackprop/real/fold-05/handright.nii.gz
# Saving guidedbackprop/real/fold-05/avg/handright.nii.gz
# Running guidedbackprop on tongue
# Saving guidedbackprop/real/fold-05/tongue.nii.gz
# Saving guidedbackprop/real/fold-05/avg/tongue.nii.gz
# Running guidedbackprop on loss
# Saving guidedbackprop/real/fold-05/loss.nii.gz
# Saving guidedbackprop/real/fold-05/avg/loss.nii.gz
# Running guidedbackprop on reward
# Saving guidedbackprop/real/fold-05/reward.nii.gz
# Saving guidedbackprop/real/fold-05/avg/reward.nii.gz
# Running guidedbackprop on mental
# Saving guidedbackprop/real/fold-05/mental.nii.gz
# Saving guidedbackprop/real/fold-05/avg/mental.nii.gz
# Running guidedbackprop on random
# Saving guidedbackprop/real/fold-05/random.nii.gz
# Saving guidedbackprop/real/fold-05/avg/random.nii.gz
# Running guidedbackprop on body
# Saving guidedbackprop/real/fold-05/body.nii.gz
# Saving guidedbackprop/real/fold-05/avg/body.nii.gz
# Running guidedbackprop on face
# Saving guidedbackprop/real/fold-05/face.nii.gz
# Saving guidedbackprop/real/fold-05/avg/face.nii.gz
# Running guidedbackprop on place
# Saving guidedbackprop/real/fold-05/place.nii.gz
# Saving guidedbackprop/real/fold-05/avg/place.nii.gz
# Running guidedbackprop on tool
# Saving guidedbackprop/real/fold-05/tool.nii.gz
# Saving guidedbackprop/real/fold-05/avg/tool.nii.gz
# Running guidedbackprop on match
# Saving guidedbackprop/real/fold-05/match.nii.gz
# Saving guidedbackprop/real/fold-05/avg/match.nii.gz
# Running guidedbackprop on relation
# Saving guidedbackprop/real/fold-05/relation.nii.gz
# Saving guidedbackprop/real/fold-05/avg/relation.nii.gz
# Running guidedbackprop on emotion
# Saving guidedbackprop/real/fold-05/emotion.nii.gz
# Saving guidedbackprop/real/fold-05/avg/emotion.nii.gz
# Running guidedbackprop on neut
# Saving guidedbackprop/real/fold-05/neut.nii.gz
# Saving guidedbackprop/real/fold-05/avg/neut.nii.gz
# Running guidedbackprop on story
# Saving guidedbackprop/real/fold-05/story.nii.gz
# Saving guidedbackprop/real/fold-05/avg/story.nii.gz
# Running guidedbackprop on math
# Saving guidedbackprop/real/fold-05/math.nii.gz
# Saving guidedbackprop/real/fold-05/avg/math.nii.gz
# Loading from config file models/CV-7folds-real/seed-2020_fold-06/config.yaml
# Running guidedbackprop on footleft
# Saving guidedbackprop/real/fold-06/footleft.nii.gz
# Saving guidedbackprop/real/fold-06/avg/footleft.nii.gz
# Running guidedbackprop on footright
# Saving guidedbackprop/real/fold-06/footright.nii.gz
# Saving guidedbackprop/real/fold-06/avg/footright.nii.gz
# Running guidedbackprop on handleft
# Saving guidedbackprop/real/fold-06/handleft.nii.gz
# Saving guidedbackprop/real/fold-06/avg/handleft.nii.gz
# Running guidedbackprop on handright
# Saving guidedbackprop/real/fold-06/handright.nii.gz
# Saving guidedbackprop/real/fold-06/avg/handright.nii.gz
# Running guidedbackprop on tongue
# Saving guidedbackprop/real/fold-06/tongue.nii.gz
# Saving guidedbackprop/real/fold-06/avg/tongue.nii.gz
# Running guidedbackprop on loss
# Saving guidedbackprop/real/fold-06/loss.nii.gz
# Saving guidedbackprop/real/fold-06/avg/loss.nii.gz
# Running guidedbackprop on reward
# Saving guidedbackprop/real/fold-06/reward.nii.gz
# Saving guidedbackprop/real/fold-06/avg/reward.nii.gz
# Running guidedbackprop on mental
# Saving guidedbackprop/real/fold-06/mental.nii.gz
# Saving guidedbackprop/real/fold-06/avg/mental.nii.gz
# Running guidedbackprop on random
# Saving guidedbackprop/real/fold-06/random.nii.gz
# Saving guidedbackprop/real/fold-06/avg/random.nii.gz
# Running guidedbackprop on body
# Saving guidedbackprop/real/fold-06/body.nii.gz
# Saving guidedbackprop/real/fold-06/avg/body.nii.gz
# Running guidedbackprop on face
# Saving guidedbackprop/real/fold-06/face.nii.gz
# Saving guidedbackprop/real/fold-06/avg/face.nii.gz
# Running guidedbackprop on place
# Saving guidedbackprop/real/fold-06/place.nii.gz
# Saving guidedbackprop/real/fold-06/avg/place.nii.gz
# Running guidedbackprop on tool
# Saving guidedbackprop/real/fold-06/tool.nii.gz
# Saving guidedbackprop/real/fold-06/avg/tool.nii.gz
# Running guidedbackprop on match
# Saving guidedbackprop/real/fold-06/match.nii.gz
# Saving guidedbackprop/real/fold-06/avg/match.nii.gz
# Running guidedbackprop on relation
# Saving guidedbackprop/real/fold-06/relation.nii.gz
# Saving guidedbackprop/real/fold-06/avg/relation.nii.gz
# Running guidedbackprop on emotion
# Saving guidedbackprop/real/fold-06/emotion.nii.gz
# Saving guidedbackprop/real/fold-06/avg/emotion.nii.gz
# Running guidedbackprop on neut
# Saving guidedbackprop/real/fold-06/neut.nii.gz
# Saving guidedbackprop/real/fold-06/avg/neut.nii.gz
# Running guidedbackprop on story
# Saving guidedbackprop/real/fold-06/story.nii.gz
# Saving guidedbackprop/real/fold-06/avg/story.nii.gz
# Running guidedbackprop on math
# Saving guidedbackprop/real/fold-06/math.nii.gz
# Saving guidedbackprop/real/fold-06/avg/math.nii.gz

# %% [markdown]
# Another sanity check for attribution methods put forth by Adebayo and colleagues is to test the similarity between attribution maps of trained networks with those of randomly initialized weights.
# If they were to be similar, we can say that the attribution map is insensitive to the model parameters, which would reduce confidence in the attribution maps of trained networks.

# %%
n_folds = 1

attributor_method = [LRP, GuidedBackprop]

model_config = read_config("hyperparameter.yaml")

seed = 1337
ctr = 0

for i, method in enumerate(attributor_method):

    method_name = str(method.__name__).lower()

    for fold in range(n_folds):
       
        g = set_random_seed(seed + ctr)
        
        model = BrainStateClassifier3d((91, 109, 91), len(class_labels), model_config)
        model.to(torch.device("cpu"));
        model.eval()
        
        out_dir_name = f"{method_name}/model-random/fold-{fold:02d}"
        if not os.path.exists(out_dir_name):
            os.makedirs(out_dir_name)

        for j in range(len(class_labels)):

            print(f"Running {method_name} on {class_labels[j]}")

            out_fname = os.path.join(out_dir_name, '%s.nii.gz' % class_labels[j])
            if os.path.isfile(out_fname):
                print(f"{out_fname} already exists. Skipping")
                continue

            dl = DataLoader(
                NiftiDataset('../t-maps/test', [class_labels[j]], 0, device=torch.device("cpu"), transform=ToTensor()),
                batch_size=20, shuffle=False, num_workers=0
            )

            for i, (volume, target) in enumerate(dl):

                attribution = attribute_with_method(method, model, volume, target)

                subject_attr = np.moveaxis(attribution.squeeze().detach().numpy(), 0, -1)
                subject_attr = z_transform_volume(subject_attr)
                avg_attr = subject_attr.mean(axis=-1)

            save_in_mni(subject_attr, out_fname)

            avg_out_name = os.path.join(out_dir_name, "avg")
            if not os.path.exists(avg_out_name):
                os.makedirs(avg_out_name)
            save_in_mni(avg_attr, os.path.join(avg_out_name, '%s.nii.gz' % class_labels[j]))
            
        ctr+=1
# Out:
# Running lrp on footleft
# Saving lrp/model-random/fold-00/footleft.nii.gz
# Saving lrp/model-random/fold-00/avg/footleft.nii.gz
# Running lrp on footright
# Saving lrp/model-random/fold-00/footright.nii.gz
# Saving lrp/model-random/fold-00/avg/footright.nii.gz
# Running lrp on handleft
# Saving lrp/model-random/fold-00/handleft.nii.gz
# Saving lrp/model-random/fold-00/avg/handleft.nii.gz
# Running lrp on handright
# Saving lrp/model-random/fold-00/handright.nii.gz
# Saving lrp/model-random/fold-00/avg/handright.nii.gz
# Running lrp on tongue
# Saving lrp/model-random/fold-00/tongue.nii.gz
# Saving lrp/model-random/fold-00/avg/tongue.nii.gz
# Running lrp on loss
# Saving lrp/model-random/fold-00/loss.nii.gz
# Saving lrp/model-random/fold-00/avg/loss.nii.gz
# Running lrp on reward
# Saving lrp/model-random/fold-00/reward.nii.gz
# Saving lrp/model-random/fold-00/avg/reward.nii.gz
# Running lrp on mental
# Saving lrp/model-random/fold-00/mental.nii.gz
# Saving lrp/model-random/fold-00/avg/mental.nii.gz
# Running lrp on random
# Saving lrp/model-random/fold-00/random.nii.gz
# Saving lrp/model-random/fold-00/avg/random.nii.gz
# Running lrp on body
# Saving lrp/model-random/fold-00/body.nii.gz
# Saving lrp/model-random/fold-00/avg/body.nii.gz
# Running lrp on face
# Saving lrp/model-random/fold-00/face.nii.gz
# Saving lrp/model-random/fold-00/avg/face.nii.gz
# Running lrp on place
# Saving lrp/model-random/fold-00/place.nii.gz
# Saving lrp/model-random/fold-00/avg/place.nii.gz
# Running lrp on tool
# Saving lrp/model-random/fold-00/tool.nii.gz
# Saving lrp/model-random/fold-00/avg/tool.nii.gz
# Running lrp on match
# Saving lrp/model-random/fold-00/match.nii.gz
# Saving lrp/model-random/fold-00/avg/match.nii.gz
# Running lrp on relation
# Saving lrp/model-random/fold-00/relation.nii.gz
# Saving lrp/model-random/fold-00/avg/relation.nii.gz
# Running lrp on emotion
# Saving lrp/model-random/fold-00/emotion.nii.gz
# Saving lrp/model-random/fold-00/avg/emotion.nii.gz
# Running lrp on neut
# Saving lrp/model-random/fold-00/neut.nii.gz
# Saving lrp/model-random/fold-00/avg/neut.nii.gz
# Running lrp on story
# Saving lrp/model-random/fold-00/story.nii.gz
# Saving lrp/model-random/fold-00/avg/story.nii.gz
# Running lrp on math
# Saving lrp/model-random/fold-00/math.nii.gz
# Saving lrp/model-random/fold-00/avg/math.nii.gz
# Running guidedbackprop on footleft
# Saving guidedbackprop/model-random/fold-00/footleft.nii.gz
# Saving guidedbackprop/model-random/fold-00/avg/footleft.nii.gz
# Running guidedbackprop on footright
# Saving guidedbackprop/model-random/fold-00/footright.nii.gz
# Saving guidedbackprop/model-random/fold-00/avg/footright.nii.gz
# Running guidedbackprop on handleft
# Saving guidedbackprop/model-random/fold-00/handleft.nii.gz
# Saving guidedbackprop/model-random/fold-00/avg/handleft.nii.gz
# Running guidedbackprop on handright
# Saving guidedbackprop/model-random/fold-00/handright.nii.gz
# Saving guidedbackprop/model-random/fold-00/avg/handright.nii.gz
# Running guidedbackprop on tongue
# Saving guidedbackprop/model-random/fold-00/tongue.nii.gz
# Saving guidedbackprop/model-random/fold-00/avg/tongue.nii.gz
# Running guidedbackprop on loss
# Saving guidedbackprop/model-random/fold-00/loss.nii.gz
# Saving guidedbackprop/model-random/fold-00/avg/loss.nii.gz
# Running guidedbackprop on reward
# Saving guidedbackprop/model-random/fold-00/reward.nii.gz
# Saving guidedbackprop/model-random/fold-00/avg/reward.nii.gz
# Running guidedbackprop on mental
# Saving guidedbackprop/model-random/fold-00/mental.nii.gz
# Saving guidedbackprop/model-random/fold-00/avg/mental.nii.gz
# Running guidedbackprop on random
# Saving guidedbackprop/model-random/fold-00/random.nii.gz
# Saving guidedbackprop/model-random/fold-00/avg/random.nii.gz
# Running guidedbackprop on body
# Saving guidedbackprop/model-random/fold-00/body.nii.gz
# Saving guidedbackprop/model-random/fold-00/avg/body.nii.gz
# Running guidedbackprop on face
# Saving guidedbackprop/model-random/fold-00/face.nii.gz
# Saving guidedbackprop/model-random/fold-00/avg/face.nii.gz
# Running guidedbackprop on place
# Saving guidedbackprop/model-random/fold-00/place.nii.gz
# Saving guidedbackprop/model-random/fold-00/avg/place.nii.gz
# Running guidedbackprop on tool
# Saving guidedbackprop/model-random/fold-00/tool.nii.gz
# Saving guidedbackprop/model-random/fold-00/avg/tool.nii.gz
# Running guidedbackprop on match
# Saving guidedbackprop/model-random/fold-00/match.nii.gz
# Saving guidedbackprop/model-random/fold-00/avg/match.nii.gz
# Running guidedbackprop on relation
# Saving guidedbackprop/model-random/fold-00/relation.nii.gz
# Saving guidedbackprop/model-random/fold-00/avg/relation.nii.gz
# Running guidedbackprop on emotion
# Saving guidedbackprop/model-random/fold-00/emotion.nii.gz
# Saving guidedbackprop/model-random/fold-00/avg/emotion.nii.gz
# Running guidedbackprop on neut
# Saving guidedbackprop/model-random/fold-00/neut.nii.gz
# Saving guidedbackprop/model-random/fold-00/avg/neut.nii.gz
# Running guidedbackprop on story
# Saving guidedbackprop/model-random/fold-00/story.nii.gz
# Saving guidedbackprop/model-random/fold-00/avg/story.nii.gz
# Running guidedbackprop on math
# Saving guidedbackprop/model-random/fold-00/math.nii.gz
# Saving guidedbackprop/model-random/fold-00/avg/math.nii.gz
