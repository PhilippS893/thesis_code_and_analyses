# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv("t-map-motor-hp-tuning-results.csv")

# %%
df.head()
# Out:
#                              Name     Agent  Runtime  \
# 0   motor-explo-1665603938.097468  lq978dqb     1077
# 1   motor-explo-1665519147.732173  kuhcmqm6     3575
# 2  motor-explo-1665548217.9417827  lq978dqb      497
# 3   motor-explo-1665577345.471957  lq978dqb      454
# 4  motor-explo-1665585434.0990279  lq978dqb      536
#
#                     Hostname Notes         GPU Type  GPU Count  Tags  \
# 0  bmig-Precision-7920-Tower     -  Quadro RTX 6000        1.0   NaN
# 1        Philipps-iMac.local     -              NaN        NaN   NaN
# 2  bmig-Precision-7920-Tower     -  Quadro RTX 6000        1.0   NaN
# 3  bmig-Precision-7920-Tower     -  Quadro RTX 6000        1.0   NaN
# 4  bmig-Precision-7920-Tower     -  Quadro RTX 6000        1.0   NaN
#
#    batch_size  dropout  kernel_size  learning_rate  best_valid_epoch  \
# 0          32      0.7            3          0.001                30
# 1          16      0.3            3          0.001                11
# ...

# %%
df = df[["batch_size", "dropout", "kernel_size", "learning_rate", "best_valid_accuracy"]]

# %%
df
# Out:
#      batch_size  dropout  kernel_size  learning_rate  best_valid_accuracy
# 0            32      0.7            3          0.001             0.992857
# 1            16      0.3            3          0.001             0.992857
# 2            16      0.6            3          0.001             0.992857
# 3            32      0.4            3          0.001             0.992857
# 4            32      0.5            3          0.001             0.992857
# ..          ...      ...          ...            ...                  ...
# 175          16      0.7            7          0.001             0.200000
# 176          16      0.3            7          0.001             0.200000
# 177           4      0.3            7          0.001             0.200000
# 178           4      0.5            7          0.001             0.200000
# 179           8      0.7            7          0.001             0.200000
#
# [180 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(30, 15))
ax = plt.axes(projection='3d')

# Data for a three-dimensional line
zline = df["best_valid_accuracy"]
xline = df["kernel_size"]
yline = df["dropout"]
ax.scatter3D(zline, yline, xline, 'gray', c=df["learning_rate"], s=df["batch_size"]*5, cmap="jet")
#ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens');
